# %%
import pandas as pd

# %%
path = 'D:/DSBA/Project/Final-Project-2/data/Text files/Question_Answer_Dataset_v1.2/S08/question_answer_pairs.txt'

# %%
df = pd.read_fwf(path,sep="\t")

# %%
df = df.iloc[:,0]
data = pd.DataFrame()

# %%
indexz = 0
for i in df.name.split('\t'):
    if indexz==5:
        break
    else:
        print(indexz)
        data[str(i)] = [x.split('\t')[indexz] for x in df]
        indexz =
# Out:
# 0
# 0
# 0
# 0
# 0
# 0

# %%
df.to_csv('D:/DSBA/Project/Final-Project-2/data/Text files/Question_Answer_Dataset_v1.2/S08/test.csv',index=False)

# %%
for i in df:
    print(i.split('\t')[0])
# Out:
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Abraham_Lincoln
# Alessandro_Volta
# ...

# %%
df[0].split('\t')[5]
# Out:
# 'data/set3/a4'

# %%
data['a'] = [1,2]

# %%
indexz
# Out:
# 2
