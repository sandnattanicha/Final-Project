# %%
import sys
import os
import speech_recognition as sr
from pydub import AudioSegment
import pandas as pd
from pathlib import Path

# %% [markdown]
# # Audio longer less than 1 minute

# %%
from google.cloud import speech_v1 as speech
from jiwer import wer
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="Key/SpeechReg-2b5d8171274a.json"

def speech_to_text(config, audio):
    client = speech.SpeechClient()
    response = client.recognize(config=config, audio=audio)
    return print_sentences(response)


def print_sentences(response):
    for result in response.results:
        best_alternative = result.alternatives[0]
        transcript = best_alternative.transcript
        confidence = best_alternative.confidence
#         ground_truth = text_ori
#         hyphothesis = {transcript}
        print("-" * 80)
        print(f"Transcript: {transcript}")
#         print(f"Error : {wer(ground_truth, hyphothesis)}")
        print(f"Confidence: {confidence:.0%}")
        print_word_offsets(best_alternative)


def print_word_offsets(alternative):
    for word in alternative.words:
        start_s = word.start_time.total_seconds()
        end_s = word.end_time.total_seconds()
        word = word.word
        print(f"{start_s:>7.3f} | {end_s:>7.3f} | {word}")
        
# text_ori = open("data/Michael.txt", "r").read()
audio = dict(uri = "gs://voicedata_speech/Voice/Michael.wav") 
config = dict(
                language_code="en-US",
                enable_automatic_punctuation=True,
                enable_word_time_offsets=True,
                model="video",
                )

speech_to_text(config, audio)
# Out:
# --------------------------------------------------------------------------------
# Transcript: Hello, you've called virtual bank. This is Helen speaking. How may I help you? Hi Helen. I think I've lost my account book. I couldn't find it. What can I do about this? Okay first could you tell me your name sir? I'm Michael Myers. Okay. Mr. Myers in this case. You had to go to the bank nearby you and give your identification card to the bank officer.
# Confidence: 86%
#   0.200 |   0.900 | Hello,
#   1.000 |   1.400 | you've
#   1.400 |   1.800 | called
#   1.800 |   2.300 | virtual
#   2.300 |   3.000 | bank.
#   3.100 |   3.300 | This
#   3.300 |   3.500 | is
#   3.500 |   3.900 | Helen
#   3.900 |   4.700 | speaking.
#   4.800 |   5.100 | How
#   5.100 |   5.400 | may
#   5.400 |   5.500 | I
#   5.500 |   5.800 | help
#   5.800 |   6.200 | you?
#   7.300 |   7.500 | Hi
#   7.500 |   8.000 | Helen.
#   8.500 |   8.700 | I
#   8.700 |   9.100 | think
#   9.100 |   9.200 | I've
#   9.200 |   9.600 | lost
#   9.600 |   9.800 | my
#   9.800 |  10.100 | account
#  10.100 |  10.700 | book.
#  11.100 |  11.200 | I
#  11.200 |  11.500 | couldn't
#  11.500 |  11.800 | find
#  11.800 |  12.100 | it.
#  12.600 |  12.800 | What
#  12.800 |  12.900 | can
#  12.900 |  13.000 | I
#  13.000 |  13.200 | do
#  13.200 |  13.500 | about
#  13.500 |  13.900 | this?
#  14.200 |  14.700 | Okay
#  14.700 |  15.500 | first
#  15.600 |  15.800 | could
#  15.800 |  15.900 | you
#  15.900 |  16.200 | tell
#  16.200 |  16.400 | me
#  16.400 |  16.600 | your
#  16.600 |  17.000 | name
#  17.000 |  17.400 | sir?
#  17.900 |  18.100 | I'm
#  18.100 |  18.400 | Michael
#  18.400 |  19.000 | Myers.
#  20.000 |  20.900 | Okay.
#  21.000 |  21.500 | Mr.
#  21.500 |  22.300 | Myers
#  22.400 |  22.700 | in
#  22.700 |  23.000 | this
#  23.000 |  23.300 | case.
#  23.300 |  23.500 | You
#  23.500 |  23.800 | had
#  23.800 |  23.900 | to
#  23.900 |  24.200 | go
#  24.200 |  24.400 | to
#  24.400 |  24.500 | the
#  24.500 |  24.900 | bank
#  24.900 |  25.600 | nearby
#  25.600 |  25.800 | you
#  25.800 |  26.000 | and
#  26.000 |  26.300 | give
#  26.300 |  26.600 | your
#  26.600 |  27.900 | identification
#  27.900 |  28.300 | card
#  28.300 |  28.400 | to
#  28.400 |  28.500 | the
#  28.500 |  28.900 | bank
#  28.900 |  29.600 | officer.
# --------------------------------------------------------------------------------
# Transcript:  They'll mange about your account book.
# Confidence: 88%
#  30.000 |  30.100 | They'll
#  30.100 |  30.500 | mange
#  30.500 |  30.900 | about
#  30.900 |  31.100 | your
#  31.100 |  31.600 | account
#  31.600 |  32.100 | book.
# --------------------------------------------------------------------------------
# Transcript:  Oh, okay. I'll go to the bank tomorrow. Thank you Helen. Thank you for using our service. Have a good day, sir.
# Confidence: 90%
#  33.400 |  33.800 | Oh,
#  34.000 |  34.400 | okay.
#  34.400 |  34.600 | I'll
#  34.600 |  34.800 | go
#  34.800 |  34.900 | to
#  34.900 |  35.000 | the
#  35.000 |  35.300 | bank
#  35.300 |  35.900 | tomorrow.
#  36.400 |  36.600 | Thank
#  36.600 |  36.800 | you
#  36.800 |  37.300 | Helen.
#  38.000 |  38.400 | Thank
#  38.400 |  38.500 | you
#  38.500 |  38.700 | for
#  38.700 |  39.200 | using
#  39.200 |  39.400 | our
#  39.400 |  40.100 | service.
#  40.300 |  40.500 | Have
#  40.500 |  40.600 | a
#  40.600 |  40.800 | good
#  40.800 |  41.000 | day,
#  41.000 |  41.500 | sir.

# %% [markdown]
# # Audio longer more than 1 minute

# %%
from google.cloud import speech

audio = speech.RecognitionAudio(uri="gs://voicedata_speech/Voice/Date.wav")
config = speech.RecognitionConfig(
            sample_rate_hertz=16000,
            language_code="en-US",
            enable_automatic_punctuation=True,
            enable_word_time_offsets=True,
            model="video")

data = []
start_all = []
end_all = []
word_all = []

def speech_to_text(config, audio):
    client = speech.SpeechClient()
    operation = client.long_running_recognize(config=config, audio=audio)
    response = operation.result(timeout=90)
    return print_sentences(response)

#     print("Waiting for operation to complete...")

def print_sentences(response):
    for result in response.results:
        best_alternative = result.alternatives[0]
        transcript = best_alternative.transcript
        confidence = best_alternative.confidence
        data.append(transcript)
        print("-" * 80)
        print(f"Transcript: {transcript}")
        print(f"Confidence: {confidence:.0%}")
        print_word_offsets(best_alternative)
        

def print_word_offsets(alternative):
    #start,end,words = [],[],[]
    for word in alternative.words:
        start_s = word.start_time.total_seconds()
        #start.append(start_s)
        end_s = word.end_time.total_seconds()
        #end.append(end_s)
        word = word.word
        #words.append(word)
#         start = (f"{start_s:>7.3f}")
#         end = (f"{end_s:>7.3f}")
#         word = (f"{word}")
#         details = {'col1': start, 'col2': end, 'col3': word }
#         df = pd.DataFrame(data=details)
#         print(df)
        print(f"{start_s:>7.3f} | {end_s:>7.3f} | {word}")
        start_all.append(start_s)
        end_all.append(end_s)
        word_all.append(word)
    return resultdict

speech_to_text(config, audio)

trans = ''.join(data)
resultdict = {'transcript':trans,'values':{'start':start_all,'end':end_all,'word':word_all}}
# Out:
# --------------------------------------------------------------------------------
# Transcript: Hello, you have called virtual bank. This is Sarah speaking. How may I help you? Hey sir, I would to refund my money back. Could you tell me why you want to refund your money? I bought something at the shop with my debit card on the 2nd of December 2019 and it debited my money twice. Okay. What is your name Madam? My name is Amy golf golf. Okay, I have Amy Gough Gough and where did you use the debit card to buy something? I bought a bag at Mega bangna it costs $800 were so sorry. In this case. We could not refund your money back. You have to talk with the store that you bought and they will manage.
# Confidence: 80%
#   0.000 |   0.500 | Hello,
#   0.500 |   0.600 | you
#   0.600 |   0.800 | have
#   0.800 |   1.100 | called
#   1.100 |   1.600 | virtual
#   1.600 |   2.000 | bank.
#   2.000 |   2.100 | This
#   2.100 |   2.300 | is
#   2.300 |   2.700 | Sarah
#   2.700 |   3.200 | speaking.
#   3.200 |   3.400 | How
#   3.400 |   3.600 | may
#   3.600 |   3.700 | I
#   3.700 |   4.000 | help
#   4.000 |   4.200 | you?
#   4.200 |   4.400 | Hey
#   4.400 |   4.700 | sir,
#   4.700 |   4.900 | I
#   4.900 |   5.100 | would
#   5.100 |   5.200 | to
#   5.200 |   5.600 | refund
#   5.600 |   5.800 | my
#   5.800 |   6.100 | money
#   6.100 |   6.400 | back.
#   6.400 |   6.600 | Could
#   6.600 |   6.700 | you
#   6.700 |   6.900 | tell
#   6.900 |   7.100 | me
#   7.100 |   7.300 | why
#   7.300 |   7.400 | you
#   7.400 |   7.700 | want
#   7.700 |   7.800 | to
#   7.800 |   8.200 | refund
#   8.200 |   8.300 | your
#   8.300 |   8.700 | money?
#   8.700 |   8.700 | I
#   8.700 |   9.000 | bought
#   9.000 |   9.500 | something
#   9.500 |   9.600 | at
#   9.600 |   9.700 | the
#   9.700 |  10.000 | shop
#  10.000 |  10.200 | with
#  10.200 |  10.300 | my
#  10.300 |  10.700 | debit
#  10.700 |  11.100 | card
#  11.100 |  11.200 | on
#  11.200 |  11.300 | the
#  11.300 |  11.600 | 2nd
#  11.600 |  11.700 | of
#  11.700 |  12.200 | December
#  12.200 |  13.200 | 2019
#  13.200 |  13.300 | and
#  13.300 |  13.400 | it
#  13.400 |  13.800 | debited
#  13.800 |  13.900 | my
#  13.900 |  14.200 | money
#  14.200 |  14.600 | twice.
#  14.600 |  14.900 | Okay.
#  14.900 |  15.100 | What
#  15.100 |  15.200 | is
#  15.200 |  15.300 | your
#  15.300 |  15.600 | name
#  15.600 |  15.900 | Madam?
#  15.900 |  16.000 | My
#  16.000 |  16.300 | name
#  16.300 |  16.500 | is
#  16.500 |  16.700 | Amy
#  16.700 |  17.100 | golf
#  17.100 |  17.400 | golf.
#  17.400 |  17.700 | Okay,
#  17.700 |  17.800 | I
#  17.800 |  18.000 | have
#  18.000 |  18.300 | Amy
#  18.300 |  18.600 | Gough
#  18.600 |  19.000 | Gough
#  19.000 |  19.100 | and
#  19.100 |  19.300 | where
#  19.300 |  19.400 | did
#  19.400 |  19.600 | you
#  19.600 |  19.800 | use
#  19.800 |  19.900 | the
#  19.900 |  20.200 | debit
#  20.200 |  20.600 | card
#  20.600 |  20.700 | to
#  20.700 |  20.900 | buy
#  20.900 |  21.400 | something?
#  21.400 |  21.500 | I
#  21.500 |  21.700 | bought
#  21.700 |  21.700 | a
#  21.700 |  22.100 | bag
#  22.100 |  22.200 | at
#  22.200 |  22.500 | Mega
#  22.500 |  22.900 | bangna
#  22.900 |  23.000 | it
#  23.000 |  23.400 | costs
#  23.400 |  24.300 | $800
#  24.300 |  24.400 | were
#  24.400 |  24.700 | so
#  24.700 |  25.100 | sorry.
#  25.100 |  25.200 | In
#  25.200 |  25.400 | this
#  25.400 |  25.800 | case.
#  25.800 |  25.900 | We
#  25.900 |  26.000 | could
#  26.000 |  26.300 | not
#  26.300 |  26.600 | refund
#  26.600 |  26.800 | your
#  26.800 |  27.000 | money
#  27.000 |  27.400 | back.
#  27.400 |  27.500 | You
#  27.500 |  27.700 | have
#  27.700 |  27.800 | to
#  27.800 |  28.100 | talk
#  28.100 |  28.200 | with
#  28.200 |  28.300 | the
#  28.300 |  28.700 | store
#  28.700 |  28.800 | that
#  28.800 |  29.000 | you
#  29.000 |  29.300 | bought
#  29.300 |  29.400 | and
#  29.400 |  29.500 | they
#  29.500 |  29.600 | will
#  29.600 |  29.900 | manage.
# --------------------------------------------------------------------------------
# Transcript:  Judge this oh, really? I do not even know. Yes madam. We're so sorry, but we could not fix this problem the store handles about this. Okay, nevermind. Thanks. Would you like another service? That is all thanks. Thank you for using our service. Have a good day.
# Confidence: 63%
#  30.000 |  30.100 | Judge
#  30.100 |  30.400 | this
#  30.400 |  30.600 | oh,
#  30.600 |  30.900 | really?
#  30.900 |  31.000 | I
#  31.000 |  31.100 | do
#  31.100 |  31.400 | not
#  31.400 |  31.600 | even
#  31.600 |  31.800 | know.
#  31.800 |  32.100 | Yes
#  32.100 |  32.400 | madam.
#  32.400 |  32.600 | We're
#  32.600 |  32.800 | so
#  32.800 |  33.300 | sorry,
#  33.300 |  33.400 | but
#  33.400 |  33.500 | we
#  33.500 |  33.700 | could
#  33.700 |  33.900 | not
#  33.900 |  34.200 | fix
#  34.200 |  34.400 | this
#  34.400 |  34.900 | problem
#  34.900 |  35.000 | the
#  35.000 |  35.400 | store
#  35.400 |  35.800 | handles
#  35.800 |  36.100 | about
#  36.100 |  36.300 | this.
#  36.300 |  36.600 | Okay,
#  36.600 |  37.200 | nevermind.
#  37.200 |  37.600 | Thanks.
#  37.600 |  37.800 | Would
#  37.800 |  37.900 | you
#  37.900 |  38.100 | like
#  38.100 |  38.400 | another
#  38.400 |  38.900 | service?
#  38.900 |  39.000 | That
#  39.000 |  39.200 | is
#  39.200 |  39.300 | all
#  39.300 |  39.700 | thanks.
#  39.700 |  40.000 | Thank
#  40.000 |  40.200 | you
#  40.200 |  40.300 | for
#  40.300 |  40.700 | using
#  40.700 |  40.800 | our
#  40.800 |  41.400 | service.
#  41.400 |  41.500 | Have
#  41.500 |  41.600 | a
#  41.600 |  41.800 | good
#  41.800 |  42.300 | day.

# %%
dict_ = resultdict['values']

# %%
df = pd.DataFrame(resultdict['values'])

# %%
import json
with open('dict.json', 'w') as outfile:
    json.dump(resultdict, outfile)

# %%
import csv
csv_tran = resultdict['transcript']
trans_writer = csv.writer(open('Transcript.csv', mode='w'))
trans_writer.writerow(trans)
# Out:
# 1745
